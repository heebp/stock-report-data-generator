# %%
# %pip install mojito2 python-dotenv pandas pymysql mysql-connector-python sqlalchemy
# Out:
# Requirement already satisfied: mojito2 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (0.1.6)
# Requirement already satisfied: python-dotenv in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (1.0.1)
# Requirement already satisfied: pandas in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (2.2.2)
# Requirement already satisfied: pymysql in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (1.1.1)
# Requirement already satisfied: mysql-connector-python in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (9.0.0)
# Requirement already satisfied: sqlalchemy in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (2.0.35)
# Requirement already satisfied: requests in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from mojito2) (2.32.3)
# Requirement already satisfied: websockets in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from mojito2) (13.1)
# Requirement already satisfied: pycryptodome in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from mojito2) (3.20.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from requests->mojito2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from requests->mojito2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from requests->mojito2) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from requests->mojito2) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

KIS_APP_KEY = os.getenv("KIS_APP_KEY")
KIS_APP_SECRET = os.getenv("KIS_APP_SECRET")
KIS_ACC_NO = os.getenv("KIS_ACC_NO")
DB_HOST = os.getenv("DB_HOST")
DB_USERNAME = os.getenv("DB_USERNAME")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_SCHEME = os.getenv("DB_SCHEME")

# %%
import pandas as pd
import requests as rq
from io import StringIO

def get_krx_otp(otp_params, headers):
  krx_gen_otp_url = 'http://data.krx.co.kr/comm/fileDn/GenerateOTP/generate.cmd'
  krx_otp = rq.post(krx_gen_otp_url, otp_params, headers = headers).text
  return krx_otp

def download_krx_sector(at_date, market = None):
  if not market:
    kospi_df = download_krx_sector(at_date, 'KOSPI')
    kosdaq_df = download_krx_sector(at_date, 'KOSDAQ')
    return pd.concat([kospi_df, kosdaq_df])

  headers = {             
    "User-Agent": "Mozilla/5.0",
    "Referer": "http://data.krx.co.kr/"
  }
  otp_params = {
      'locale': 'ko_KR',
      'trdDd': at_date,
      'money': '1',
      'csvxls_isNo': 'false',
      'name': 'fileDown',
      'url': 'dbms/MDC/STAT/standard/MDCSTAT01901'
  }
  if market == 'KOSPI':
    otp_params |= { 'mktId': 'STK' }
  elif market == 'KOSDAQ':
    otp_params |= { 'mktId': 'KSQ', 'segTpCd': 'ALL' }

  otp = get_krx_otp(otp_params, headers)

  download_url = 'http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd'
  download_params = {
      'code': otp
  }
  res = rq.post(download_url, download_params, headers = headers)
  res.encoding = 'euc-kr'
  return pd.read_csv(StringIO(res.text))

# %%
import pandas as pd
import requests as rq
from io import StringIO


def get_krx_index_otp(otp_params, headers):
  krx_gen_otp_url = 'http://data.krx.co.kr/comm/fileDn/GenerateOTP/generate.cmd'
  krx_otp = rq.post(krx_gen_otp_url, otp_params, headers = headers).text
  return krx_otp

def download_krx_index(at_date, market = None):
  if not market:
    kospi_df = download_krx_index(at_date, 'KOSPI')
    kosdaq_df = download_krx_index(at_date, 'KOSDAQ')
    return pd.concat([kospi_df, kosdaq_df])

  headers = {             
    "User-Agent": "Mozilla/5.0",
    "Referer": "http://data.krx.co.kr/"
  }
  otp_params = {
      'locale': 'ko_KR',
      'trdDd': at_date,
      'money': '1',
      'csvxls_isNo': 'false',
      'name': 'fileDown',
      'url': 'dbms/MDC/STAT/standard/MDCSTAT03501'
  }
  if market == 'KOSPI':
    otp_params |= { 'mktId': 'STK' }
  elif market == 'KOSDAQ':
    otp_params |= { 'mktId': 'KSQ', 'segTpCd': 'ALL' }

  otp = get_krx_index_otp(otp_params, headers)

  download_url = 'http://data.krx.co.kr/comm/fileDn/download_csv/download.cmd'
  download_params = {
      'code': otp
  }
  res = rq.post(download_url, download_params, headers = headers)
  res.encoding = 'euc-kr'
  return pd.read_csv(StringIO(res.text))

# %%
import datetime

# 현재 날짜를 YYYYMMDD 형식으로 변환
now = datetime.datetime.now()
current_date_str = now.strftime('%Y%m%d')

# %%
df_info = download_krx_sector(current_date_str)

# %%
df_index = download_krx_index(current_date_str)

# %%
df_info
# Out:
#               표준코드    단축코드      한글 종목명  한글 종목약명                        영문 종목명  \
# 0     KR7095570008  095570   AJ네트웍스보통주   AJ네트웍스          AJ Networks Co.,Ltd.
# 1     KR7006840003  006840    AK홀딩스보통주    AK홀딩스             AK Holdings, Inc.
# 2     KR7282330000  282330   BGF리테일보통주   BGF리테일                    BGF Retail
# 3     KR7027410000  027410      BGF보통주      BGF                           BGF
# 4     KR7138930003  138930  BNK금융지주보통주  BNK금융지주      BNK Financial Group Inc.
# ...            ...     ...         ...      ...                           ...
# 1750  KR7024060006  024060        흥구석유     흥구석유                     HeunguOil
# 1751  KR7010240000  010240          흥국       흥국   HEUNGKUK METALTECH CO.,LTD.
# 1752  KR7189980006  189980      흥국에프엔비   흥국에프엔비         HYUNGKUK F&B Co., Ltd
# 1753  KR7037440005  037440  희림종합건축사사무소       희림  Heerim Architects & Planners
# 1754  KR7238490007  238490          힘스       힘스                HIMS CO., LTD.
#
#              상장일    시장구분 증권구분    소속부 주식종류   액면가      상장주식수
# 0     2015/08/21   KOSPI   주권    NaN  보통주  1000   45252759
# 1     1999/08/11   KOSPI   주권    NaN  보통주  5000   13247561
# 2     2017/12/08   KOSPI   주권    NaN  보통주  1000   17283906
# 3     2014/05/19   KOSPI   주권    NaN  보통주  1000   95716791
# 4     2011/03/30   KOSPI   주권    NaN  보통주  5000  320436727
# ...          ...     ...  ...    ...  ...   ...        ...
# 1750  1994/12/07  KOSDAQ   주권  중견기업부  보통주   100   15000000
# 1751  2009/05/12  KOSDAQ   주권  우량기업부  보통주   500   12322696
# 1752  2015/08/07  KOSDAQ   주권  우량기업부  보통주   100   40137827
# 1753  2000/02/03  KOSDAQ   주권  우량기업부  보통주   500   13922475
# 1754  2017/07/20  KOSDAQ   주권  벤처기업부  보통주   500   11312236
#
# [2714 rows x 12 columns]

# %%
df_index
# Out:
#         종목코드      종목명      종가    대비   등락률      EPS     PER   선행 EPS  선행 PER  \
# 0     095570   AJ네트웍스    4700    20  0.43    367.0   12.81    781.0    6.02
# 1     006840    AK홀딩스   12950    60  0.47   2635.0    4.91      NaN     NaN
# 2     027410      BGF    3565     5  0.14    813.0    4.38    650.0    5.48
# 3     282330   BGF리테일  113900  -800 -0.70  11337.0   10.05  11788.0    9.66
# 4     138930  BNK금융지주    9000   -40 -0.44   1905.0    4.72   2628.0    3.42
# ...      ...      ...     ...   ...   ...      ...     ...      ...     ...
# 1730  024060     흥구석유   19090  1610  9.21     78.0  244.74      NaN     NaN
# 1731  010240       흥국    4930    35  0.72   1182.0    4.17      NaN     NaN
# 1732  189980   흥국에프엔비    1802   -30 -1.64    221.0    8.15    222.0    8.10
# 1733  037440       희림    5130   -70 -1.35    489.0   10.49      NaN     NaN
# 1734  238490       힘스    4800  -100 -2.04    511.0    9.39      NaN     NaN
#
#           BPS   PBR  주당배당금  배당수익률
# 0      9326.0  0.50    270   5.74
# 1     44339.0  0.29    200   1.54
# 2     17286.0  0.21    120   3.37
# 3     62197.0  1.83   4100   3.60
# 4     31746.0  0.28    510   5.67
# ...       ...   ...    ...    ...
# 1730   5440.0  3.51     50   0.26
# 1731   8598.0  0.57    240   4.87
# 1732   2449.0  0.74     40   2.22
# 1733   5583.0  0.92    150   2.92
# 1734   6174.0  0.78     50   1.04
#
# [2664 rows x 13 columns]

# %%
df_info_mapping = {
    '단축코드': 'SHORT_CODE',
}

df_index_mapping = {
    '종목코드': 'SHORT_CODE',
}

# 컬럼명 매핑 적용
df_info.rename(columns=df_info_mapping, inplace=True)
df_index.rename(columns=df_index_mapping, inplace=True)

# %%
merged_df = pd.merge(df_info, df_index, on='SHORT_CODE', how='outer')

# %%
merged_df
# Out:
#               표준코드 SHORT_CODE         한글 종목명     한글 종목약명  \
# 0     KR7000020008     000020        동화약품보통주        동화약품
# 1     KR7000040006     000040       KR모터스보통주       KR모터스
# 2     KR7000050005     000050          경방보통주          경방
# 3     KR7000070003     000070       삼양홀딩스보통주       삼양홀딩스
# 4     KR7000071001     000075      삼양홀딩스1우선주      삼양홀딩스우
# ...            ...        ...            ...         ...
# 2709  KR8392080006     950170           제이티씨         JTC
# 2710  KR8344390008     950190        고스트스튜디오     고스트스튜디오
# 2711  KR8840150005     950200            소마젠         소마젠
# 2712  KR8702070002     950210  프레스티지바이오파마KDR  프레스티지바이오파마
# 2713  KR8840140006     950220          네오이뮨텍       네오이뮨텍
#
#                               영문 종목명         상장일    시장구분    증권구분          소속부  \
# 0                       DongwhaPharm  1976/03/24   KOSPI      주권          NaN
# 1                          KR MOTORS  1976/05/25   KOSPI      주권          NaN
# 2                          Kyungbang  1956/03/03   KOSPI      주권          NaN
# 3                    SAMYANGHOLDINGS  1968/12/27   KOSPI      주권          NaN
# 4                SAMYANGHOLDINGS(1P)  1992/02/21   KOSPI      주권          NaN
# ...                              ...         ...     ...     ...          ...
# 2709                        JTC Inc.  2018/04/06  KOSDAQ  주식예탁증권  외국기업(소속부없음)
# 2710                    GHOST STUDIO  2020/08/18  KOSDAQ  주식예탁증권  외국기업(소속부없음)
# 2711                  Psomagen, Inc.  2020/07/13  KOSDAQ  주식예탁증권  외국기업(소속부없음)
# 2712  PRESTIGE BIOPHARMA LIMITED KDR  2021/02/05   KOSPI  주식예탁증권          NaN
# 2713             NeoImmuneTech, Inc.  2021/03/16  KOSDAQ  주식예탁증권  외국기업(소속부없음)
#
#        주식종류  ...      대비   등락률      EPS   PER  선행 EPS  선행 PER       BPS   PBR  \
# 0       보통주  ...  -120.0 -1.55    991.0  7.71     NaN     NaN   13413.0  0.57
# 1       보통주  ...    -2.0 -0.36      NaN   NaN     NaN     NaN     618.0  0.90
# 2       보통주  ...   -70.0 -1.14      NaN   NaN     NaN     NaN   29623.0  0.20
# 3       보통주  ... -1500.0 -1.93  22269.0  3.43     NaN     NaN  257475.0  0.30
# 4     구형우선주  ...   400.0  0.71      NaN   NaN     NaN     NaN       NaN   NaN
# ...     ...  ...     ...   ...      ...   ...     ...     ...       ...   ...
# 2709    보통주  ...     NaN   NaN      NaN   NaN     NaN     NaN       NaN   NaN
# 2710    보통주  ...     NaN   NaN      NaN   NaN     NaN     NaN       NaN   NaN
# 2711    보통주  ...     NaN   NaN      NaN   NaN     NaN     NaN       NaN   NaN
# 2712    보통주  ...     NaN   NaN      NaN   NaN     NaN     NaN       NaN   NaN
# 2713    보통주  ...     NaN   NaN      NaN   NaN     NaN     NaN       NaN   NaN
#
#        주당배당금  배당수익률
# 0      180.0   2.36
# 1        0.0   0.00
# 2      125.0   2.07
# 3     3500.0   4.58
# 4     3550.0   6.28
# ...      ...    ...
# 2709     NaN    NaN
# 2710     NaN    NaN
# 2711     NaN    NaN
# 2712     NaN    NaN
# 2713     NaN    NaN
#
# [2714 rows x 24 columns]

# %%
merged_df_column_mapping = {
    '단축코드': 'SHORT_CODE',
    # '서브카테고리' : 'SUB_CATEGORY_ID',
    '한글 종목약명': 'STOCK_NAME',
    '표준코드': 'STANDARD_CODE',
    '시장구분': 'STOCK_EXCHANGE_MARKET',
    '상장주식수': 'MARKET_CAPITALIZATION',
    '시가': 'OPEN_PRICE',
    '종가': 'CLOSED_PRICE',
    '고가': 'HIGH_PRICE',
    '저가': 'LOW_PRICE',
    '거래정지': 'STOCK_TRADE_STATUS',
}


merged_df.rename(columns=merged_df_column_mapping, inplace=True)

# %%
real_index = [
 'SHORT_CODE',
 'STOCK_NAME',
 'STANDARD_CODE',
 'STOCK_EXCHANGE_MARKET',
 'MARKET_CAPITALIZATION',
 'EPS',
 'PER',
 'BPS',
 'PBR',
]

merged_df = merged_df[real_index]

# %%
for column in [
 'SHORT_CODE',
 'SUB_CATEGORY_ID',
 'STOCK_NAME',
 'STANDARD_CODE',
 'STOCK_EXCHANGE_MARKET',
 'MARKET_CAPITALIZATION',
 'OPEN_PRICE',
 'CLOSED_PRICE',
 'HIGH_PRICE',
 'LOW_PRICE',
 'STOCK_TRADE_STATUS']:
    if column not in merged_df.columns:
        merged_df[column] = 1
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_596\1445798947.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df[column] = 1
# C:\Users\student\AppData\Local\Temp\ipykernel_596\1445798947.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df[column] = 1
# C:\Users\student\AppData\Local\Temp\ipykernel_596\1445798947.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df[column] = 1
# C:\Users\student\AppData\Local\Temp\ipykernel_596\1445798947.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df[column] = 1
# C:\Users\student\AppData\Local\Temp\ipykernel_596\1445798947.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df[column] = 1
# C:\Users\student\AppData\Local\Temp\ipykernel_596\1445798947.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df[column] = 1

# %%
columns_to_keep = [
 'SHORT_CODE',
 'SUB_CATEGORY_ID',
 'STOCK_NAME',
 'STANDARD_CODE',
 'STOCK_EXCHANGE_MARKET',
 'EPS',
 'PER',
 'BPS',
 'PBR',
 'OPEN_PRICE',
 'CLOSED_PRICE',
 'HIGH_PRICE',
 'LOW_PRICE',
 'MARKET_CAPITALIZATION',
 'STOCK_TRADE_STATUS'
]

merged_df = merged_df[columns_to_keep]

# %%
merged_df
# Out:
#      SHORT_CODE  SUB_CATEGORY_ID  STOCK_NAME STANDARD_CODE  \
# 0        000020                1        동화약품  KR7000020008
# 1        000040                1       KR모터스  KR7000040006
# 2        000050                1          경방  KR7000050005
# 3        000070                1       삼양홀딩스  KR7000070003
# 4        000075                1      삼양홀딩스우  KR7000071001
# ...         ...              ...         ...           ...
# 2709     950170                1         JTC  KR8392080006
# 2710     950190                1     고스트스튜디오  KR8344390008
# 2711     950200                1         소마젠  KR8840150005
# 2712     950210                1  프레스티지바이오파마  KR8702070002
# 2713     950220                1       네오이뮨텍  KR8840140006
#
#      STOCK_EXCHANGE_MARKET      EPS   PER       BPS   PBR  OPEN_PRICE  \
# 0                    KOSPI    991.0  7.71   13413.0  0.57           1
# 1                    KOSPI      NaN   NaN     618.0  0.90           1
# 2                    KOSPI      NaN   NaN   29623.0  0.20           1
# 3                    KOSPI  22269.0  3.43  257475.0  0.30           1
# 4                    KOSPI      NaN   NaN       NaN   NaN           1
# ...                    ...      ...   ...       ...   ...         ...
# 2709                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2710                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2711                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2712                 KOSPI      NaN   NaN       NaN   NaN           1
# 2713                KOSDAQ      NaN   NaN       NaN   NaN           1
#
#       CLOSED_PRICE  HIGH_PRICE  LOW_PRICE  MARKET_CAPITALIZATION  \
# 0                1           1          1               27931470
# 1                1           1          1               60132868
# 2                1           1          1               27415270
# 3                1           1          1                8564271
# 4                1           1          1                 304058
# ...            ...         ...        ...                    ...
# 2709             1           1          1               51746348
# 2710             1           1          1               13579892
# 2711             1           1          1               19236053
# 2712             1           1          1               60096155
# 2713             1           1          1               98867465
#
#       STOCK_TRADE_STATUS
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 2709                   1
# 2710                   1
# 2711                   1
# 2712                   1
# 2713                   1
#
# [2714 rows x 15 columns]

# %%
for column in [
 'SHORT_CODE',
 'SUB_CATEGORY_ID',
 'STOCK_NAME',
 'STANDARD_CODE',
 'STOCK_EXCHANGE_MARKET',
 'MARKET_CAPITALIZATION',
 'OPEN_PRICE',
 'CLOSED_PRICE',
 'HIGH_PRICE',
 'LOW_PRICE',
 'STOCK_TRADE_STATUS']:
    if column not in merged_df.columns:
        merged_df[column] = -1

# %%
merged_df
# Out:
#      SHORT_CODE  SUB_CATEGORY_ID  STOCK_NAME STANDARD_CODE  \
# 0        000020                1        동화약품  KR7000020008
# 1        000040                1       KR모터스  KR7000040006
# 2        000050                1          경방  KR7000050005
# 3        000070                1       삼양홀딩스  KR7000070003
# 4        000075                1      삼양홀딩스우  KR7000071001
# ...         ...              ...         ...           ...
# 2709     950170                1         JTC  KR8392080006
# 2710     950190                1     고스트스튜디오  KR8344390008
# 2711     950200                1         소마젠  KR8840150005
# 2712     950210                1  프레스티지바이오파마  KR8702070002
# 2713     950220                1       네오이뮨텍  KR8840140006
#
#      STOCK_EXCHANGE_MARKET      EPS   PER       BPS   PBR  OPEN_PRICE  \
# 0                    KOSPI    991.0  7.71   13413.0  0.57           1
# 1                    KOSPI      NaN   NaN     618.0  0.90           1
# 2                    KOSPI      NaN   NaN   29623.0  0.20           1
# 3                    KOSPI  22269.0  3.43  257475.0  0.30           1
# 4                    KOSPI      NaN   NaN       NaN   NaN           1
# ...                    ...      ...   ...       ...   ...         ...
# 2709                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2710                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2711                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2712                 KOSPI      NaN   NaN       NaN   NaN           1
# 2713                KOSDAQ      NaN   NaN       NaN   NaN           1
#
#       CLOSED_PRICE  HIGH_PRICE  LOW_PRICE  MARKET_CAPITALIZATION  \
# 0                1           1          1               27931470
# 1                1           1          1               60132868
# 2                1           1          1               27415270
# 3                1           1          1                8564271
# 4                1           1          1                 304058
# ...            ...         ...        ...                    ...
# 2709             1           1          1               51746348
# 2710             1           1          1               13579892
# 2711             1           1          1               19236053
# 2712             1           1          1               60096155
# 2713             1           1          1               98867465
#
#       STOCK_TRADE_STATUS
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 2709                   1
# 2710                   1
# 2711                   1
# 2712                   1
# 2713                   1
#
# [2714 rows x 15 columns]

# %%
df_index
# Out:
#      SHORT_CODE      종목명      종가    대비   등락률      EPS     PER   선행 EPS  \
# 0        095570   AJ네트웍스    4700    20  0.43    367.0   12.81    781.0
# 1        006840    AK홀딩스   12950    60  0.47   2635.0    4.91      NaN
# 2        027410      BGF    3565     5  0.14    813.0    4.38    650.0
# 3        282330   BGF리테일  113900  -800 -0.70  11337.0   10.05  11788.0
# 4        138930  BNK금융지주    9000   -40 -0.44   1905.0    4.72   2628.0
# ...         ...      ...     ...   ...   ...      ...     ...      ...
# 1730     024060     흥구석유   19090  1610  9.21     78.0  244.74      NaN
# 1731     010240       흥국    4930    35  0.72   1182.0    4.17      NaN
# 1732     189980   흥국에프엔비    1802   -30 -1.64    221.0    8.15    222.0
# 1733     037440       희림    5130   -70 -1.35    489.0   10.49      NaN
# 1734     238490       힘스    4800  -100 -2.04    511.0    9.39      NaN
#
#       선행 PER      BPS   PBR  주당배당금  배당수익률
# 0       6.02   9326.0  0.50    270   5.74
# 1        NaN  44339.0  0.29    200   1.54
# 2       5.48  17286.0  0.21    120   3.37
# 3       9.66  62197.0  1.83   4100   3.60
# 4       3.42  31746.0  0.28    510   5.67
# ...      ...      ...   ...    ...    ...
# 1730     NaN   5440.0  3.51     50   0.26
# 1731     NaN   8598.0  0.57    240   4.87
# 1732    8.10   2449.0  0.74     40   2.22
# 1733     NaN   5583.0  0.92    150   2.92
# 1734     NaN   6174.0  0.78     50   1.04
#
# [2664 rows x 13 columns]

# %%
merged_df
# Out:
#      SHORT_CODE  SUB_CATEGORY_ID  STOCK_NAME STANDARD_CODE  \
# 0        000020                1        동화약품  KR7000020008
# 1        000040                1       KR모터스  KR7000040006
# 2        000050                1          경방  KR7000050005
# 3        000070                1       삼양홀딩스  KR7000070003
# 4        000075                1      삼양홀딩스우  KR7000071001
# ...         ...              ...         ...           ...
# 2709     950170                1         JTC  KR8392080006
# 2710     950190                1     고스트스튜디오  KR8344390008
# 2711     950200                1         소마젠  KR8840150005
# 2712     950210                1  프레스티지바이오파마  KR8702070002
# 2713     950220                1       네오이뮨텍  KR8840140006
#
#      STOCK_EXCHANGE_MARKET      EPS   PER       BPS   PBR  OPEN_PRICE  \
# 0                    KOSPI    991.0  7.71   13413.0  0.57           1
# 1                    KOSPI      NaN   NaN     618.0  0.90           1
# 2                    KOSPI      NaN   NaN   29623.0  0.20           1
# 3                    KOSPI  22269.0  3.43  257475.0  0.30           1
# 4                    KOSPI      NaN   NaN       NaN   NaN           1
# ...                    ...      ...   ...       ...   ...         ...
# 2709                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2710                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2711                KOSDAQ      NaN   NaN       NaN   NaN           1
# 2712                 KOSPI      NaN   NaN       NaN   NaN           1
# 2713                KOSDAQ      NaN   NaN       NaN   NaN           1
#
#       CLOSED_PRICE  HIGH_PRICE  LOW_PRICE  MARKET_CAPITALIZATION  \
# 0                1           1          1               27931470
# 1                1           1          1               60132868
# 2                1           1          1               27415270
# 3                1           1          1                8564271
# 4                1           1          1                 304058
# ...            ...         ...        ...                    ...
# 2709             1           1          1               51746348
# 2710             1           1          1               13579892
# 2711             1           1          1               19236053
# 2712             1           1          1               60096155
# 2713             1           1          1               98867465
#
#       STOCK_TRADE_STATUS
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 2709                   1
# 2710                   1
# 2711                   1
# 2712                   1
# 2713                   1
#
# [2714 rows x 15 columns]

# %%
merged_df['STOCK_EXCHANGE_MARKET'] = merged_df['STOCK_EXCHANGE_MARKET'].map({'KOSPI': "0", 'KOSDAQ': "1"})

# %%
merged_df
# Out:
#      SHORT_CODE  SUB_CATEGORY_ID  STOCK_NAME STANDARD_CODE  \
# 0        000020                1        동화약품  KR7000020008
# 1        000040                1       KR모터스  KR7000040006
# 2        000050                1          경방  KR7000050005
# 3        000070                1       삼양홀딩스  KR7000070003
# 4        000075                1      삼양홀딩스우  KR7000071001
# ...         ...              ...         ...           ...
# 2709     950170                1         JTC  KR8392080006
# 2710     950190                1     고스트스튜디오  KR8344390008
# 2711     950200                1         소마젠  KR8840150005
# 2712     950210                1  프레스티지바이오파마  KR8702070002
# 2713     950220                1       네오이뮨텍  KR8840140006
#
#      STOCK_EXCHANGE_MARKET      EPS   PER       BPS   PBR  OPEN_PRICE  \
# 0                        0    991.0  7.71   13413.0  0.57           1
# 1                        0      NaN   NaN     618.0  0.90           1
# 2                        0      NaN   NaN   29623.0  0.20           1
# 3                        0  22269.0  3.43  257475.0  0.30           1
# 4                        0      NaN   NaN       NaN   NaN           1
# ...                    ...      ...   ...       ...   ...         ...
# 2709                     1      NaN   NaN       NaN   NaN           1
# 2710                     1      NaN   NaN       NaN   NaN           1
# 2711                     1      NaN   NaN       NaN   NaN           1
# 2712                     0      NaN   NaN       NaN   NaN           1
# 2713                     1      NaN   NaN       NaN   NaN           1
#
#       CLOSED_PRICE  HIGH_PRICE  LOW_PRICE  MARKET_CAPITALIZATION  \
# 0                1           1          1               27931470
# 1                1           1          1               60132868
# 2                1           1          1               27415270
# 3                1           1          1                8564271
# 4                1           1          1                 304058
# ...            ...         ...        ...                    ...
# 2709             1           1          1               51746348
# 2710             1           1          1               13579892
# 2711             1           1          1               19236053
# 2712             1           1          1               60096155
# 2713             1           1          1               98867465
#
#       STOCK_TRADE_STATUS
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 2709                   1
# 2710                   1
# 2711                   1
# 2712                   1
# 2713                   1
#
# [2714 rows x 15 columns]

# %%
from sqlalchemy import create_engine
# MySQL 데이터베이스 연결 설정
db_username = DB_USERNAME
db_password = DB_PASSWORD
db_host = DB_HOST
db_name = DB_SCHEME

# SQLAlchemy 엔진 생성
engine = create_engine(f'mysql+pymysql://{db_username}:{db_password}@{db_host}/{db_name}')

merged_df.to_sql(name='STOCK', con=engine, if_exists='append', index=False)
# Out:
# 2714
