# %%
# %pip install mojito2 python-dotenv pandas pymysql mysql-connector-python sqlalchemy
# Out:
# Requirement already satisfied: mojito2 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (0.1.6)
# Requirement already satisfied: python-dotenv in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (1.0.1)
# Requirement already satisfied: pandas in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (2.2.3)
# Requirement already satisfied: pymysql in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (1.1.1)
# Requirement already satisfied: mysql-connector-python in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (9.0.0)
# Requirement already satisfied: sqlalchemy in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (2.0.35)
# Requirement already satisfied: requests in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from mojito2) (2.32.3)
# Requirement already satisfied: websockets in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from mojito2) (13.1)
# Requirement already satisfied: pycryptodome in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from mojito2) (3.20.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from requests->mojito2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from requests->mojito2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from requests->mojito2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\student\documents\stock-report-data-generator\stock-info\lib\site-packages (from requests->mojito2) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

KIS_APP_KEY = os.getenv("KIS_APP_KEY")
KIS_APP_SECRET = os.getenv("KIS_APP_SECRET")
KIS_ACC_NO = os.getenv("KIS_ACC_NO")
DB_HOST = os.getenv("DB_HOST")
DB_USERNAME = os.getenv("DB_USERNAME")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_SCHEME = os.getenv("DB_SCHEME")

# %%
import mojito

broker = mojito.KoreaInvestment(
    api_key=KIS_APP_KEY,
    api_secret=KIS_APP_SECRET,
    acc_no=KIS_ACC_NO
)

# %%
import pandas as pd

# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

pd.reset_option('display.max_rows', None)
# pd.reset_option('display.max_columns', None)

# %%
symbols_kospi = broker.fetch_kospi_symbols()
symbols_kospi[symbols_kospi['그룹코드'] == 'ST' ]
# Out:
#         단축코드          표준코드           한글명 그룹코드  시가총액규모  지수업종대분류  지수업종중분류  \
# 103   000020  KR7000020008          동화약품   ST     3.0        0        9
# 104   000040  KR7000040006         KR모터스   ST     3.0        0       15
# 105   000050  KR7000050005            경방   ST     3.0        0       16
# 106   000070  KR7000070003         삼양홀딩스   ST     2.0        0       21
# 107   000075  KR7000071001        삼양홀딩스우   ST     0.0        0       21
# ...      ...           ...           ...  ...     ...      ...      ...
# 1755  462870  KR7462870007          시프트업   ST     0.0        0       26
# 1782  465770  KR7465770006      STX그린로지스   ST     3.0        0       19
# 1845  475150  KR7475150009        SK이터닉스   ST     2.0        0       18
# 1921  487570  KR7487570004          HS효성   ST     3.0        0       21
# 1939  489790  KR7489790006  한화인더스트리얼솔루션즈   ST     0.0        0       21
#
#       지수업종소분류 제조업 저유동성 지배구조지수종목 KOSPI200섹터업종 KOSPI100 KOSPI50 KRX  ETP ELW발행  \
# 103         0   Y    N        N            0        N       N   Y  NaN     N
# 104         0   Y    N        N            0        N       N   N  NaN     N
# 105         0   N    N        N            0        N       N   N  NaN     N
# 106         0   N    N        N            0        N       N   N  NaN     N
# 107         0   N    Y        N            0        N       N   N  NaN     N
# ...       ...  ..  ...      ...          ...      ...     ...  ..  ...   ...
# 1755        0   N    N      NaN            0        N       N   N  NaN     N
# 1782        0   N    N      NaN            0        N       N   N  NaN     N
# 1845        0   N    N      NaN            0        N       N   N  NaN     N
# 1921        0   N    N      NaN            0        N       N   Y  NaN     N
# 1939        0   N    N      NaN            0        N       N   N  NaN     N
#
#      KRX100 KRX자동차 KRX반도체 KRX바이오 KRX은행 SPAC KRX에너지화학 KRX철강  단기과열 KRX미디어통신  \
# 103       N      N      N      Y     N    N        N     N     0        N
# 104       N      N      N      N     N    N        N     N     0        N
# 105       N      N      N      N     N    N        N     N     0        N
# 106       N      N      N      N     N    N        N     N     0        N
# 107       N      N      N      N     N    N        N     N     0        N
# ...     ...    ...    ...    ...   ...  ...      ...   ...   ...      ...
# 1755      N    NaN    NaN    NaN   NaN    N      NaN   NaN     0      NaN
# 1782      N    NaN    NaN    NaN   NaN    N      NaN   NaN     0      NaN
# 1845      N    NaN    NaN    NaN   NaN    N      NaN   NaN     0      NaN
# 1921      N    NaN    NaN    NaN   NaN    N      NaN   NaN     0      NaN
# 1939      N    NaN    NaN    NaN   NaN    N      NaN   NaN     0      NaN
#
#      KRX건설 Non1 KRX증권 KRX선박 KRX섹터_보험 KRX섹터_운송  SRI    기준가  매매수량단위  시간외수량단위  \
# 103      N    N     N     N        N        N    N   7850       1        1
# 104      N    N     N     N        N        N    N    568       1        1
# 105      N    N     N     N        N        N    N   6260       1        1
# 106      N    N     N     N        N        N    N  79100       1        1
# 107      N    N     N     N        N        N    N  57200       1        1
# ...    ...  ...   ...   ...      ...      ...  ...    ...     ...      ...
# 1755   NaN    N   NaN   NaN      NaN      NaN  NaN  57900       1        1
# 1782   NaN    N   NaN   NaN      NaN      NaN  NaN  13410       1        1
# 1845   NaN    N   NaN   NaN      NaN      NaN  NaN  18810       1        1
# 1921   NaN    N   NaN   NaN      NaN      NaN  NaN  42500       1        1
# 1939   NaN    N   NaN   NaN      NaN      NaN  NaN  42700       1        1
#
#      거래정지 정리매매 관리종목  시장경고 경고예고 불성실공시 우회상장  락구분  액면변경  증자구분  증거금비율 신용가능  신용기간  \
# 103     N    N    N     0    N     N    N    0     0     0     60    Y    90
# 104     N    N    N     0    N     N    N    0     0     0    100    N    90
# 105     N    N    N     0    N     N    N    0     0     0    100    N    90
# 106     N    N    N     0    N     N    N    0     0     0     40    Y    90
# 107     N    N    Y     0    N     N    N    0     0     0    100    N    90
# ...   ...  ...  ...   ...  ...   ...  ...  ...   ...   ...    ...  ...   ...
# 1755    N    N    N     0    N     N    N    0     0     0    100    N    90
# 1782    N    N    N     0    N     N    N    0     0     0    100    N    90
# 1845    N    N    N     0    N     N    N    0     0     0    100    N    90
# 1921    N    N    N     0    N     N    N    0     0     0    100    N    90
# 1939    N    N    N     0    N     N    N    0     0     0    100    N    90
#
#         전일거래량   액면가      상장일자   상장주수          자본금   결산월  공모가  우선주  공매도과열 이상급등  \
# 103     38071  1000  19760324  27931  27931470000  12.0  NaN    0    NaN    N
# 104     72566   500  19760525  60132  30066434000  12.0  NaN    0    NaN    N
# 105     14143   500  19560303  27415  13707635000  12.0  NaN    0    NaN    N
# 106      6729  5000  19681227   8564  42821355000  12.0  NaN    0    NaN    N
# 107        26  5000  19920221    304   1520290000  12.0  NaN    1    NaN    N
# ...       ...   ...       ...    ...          ...   ...  ...  ...    ...  ...
# 1755    97394   200  20240711  58334  11666944000  12.0  NaN    0    NaN    N
# 1782  1489503  2500  20230915   7171  17927580000  12.0  NaN    0    NaN    N
# 1845   902408   200  20240329  33691   6738379000  12.0  NaN    0    NaN    N
# 1921     5667  5000  20240729   3725  18629635000  12.0  NaN    0    NaN    N
# 1939        0   500  20240927  50488  25244195000  12.0  NaN    0    NaN    N
#
#      KRX300 KOSPI    매출액  영업이익  경상이익  당기순이익    ROE        기준년월   시가총액 그룹사코드  \
# 103       N     Y   2340   112    97     60   3.49  20240630.0   2192   NaN
# 104       N     Y    336   -80  -106   -106 -59.34  20240630.0    341   NaN
# 105       N     Y   1930   134    71     46   1.25  20240630.0   1716   NaN
# 106       N     Y  17885   899  1072    839   4.50  20240630.0   6774   NaN
# 107       N     N      0     0     0      0   0.00         NaN    173   NaN
# ...     ...   ...    ...   ...   ...    ...    ...         ...    ...   ...
# 1755      N     Y   1686  1111  1143   1067  99.16  20231231.0  33775   NaN
# 1782      N     Y    218    36    34     34  20.26  20240630.0    961   NaN
# 1845      N     Y    188   -19   -34    -41   0.00  20240630.0   6337   535
# 1921      Y     Y      0     0     0      0   0.00         NaN   1583   971
# 1939      N     N      0     0     0      0   0.00         NaN      0   NaN
#
#      회사신용한도초과 담보대출가능 대주가능
# 103         N      N    N
# 104         N      N    N
# 105         N      N    N
# 106         N      N    N
# 107         N      N    N
# ...       ...    ...  ...
# 1755        N      N    N
# 1782        N      N    N
# 1845        N      N    N
# 1921        N      N    N
# 1939        N      N    N
#
# [929 rows x 73 columns]

# %%
symbols_kosdaq = broker.fetch_kosdaq_symbols()
symbols_kosdaq[symbols_kosdaq['그룹코드'] == 'ST']
# Out:
#         단축코드          표준코드         한글명 그룹코드  시가총액규모  지수업종대분류  지수업종중분류  \
# 7     000250  KR7000250001       삼천당제약   ST     1.0        0     1009
# 8     000440  KR7000440008      중앙에너비스   ST     3.0        0     1011
# 9     001000  KR7001000009        신라섬유   ST     3.0     1006        0
# 10    001540  KR7001540004        안국약품   ST     3.0        0     1009
# 11    001810  KR7001810001        무림SP   ST     3.0        0     1009
# ...      ...           ...         ...  ...     ...      ...      ...
# 1738  479880  KR7479880007    한국제15호스팩   ST     0.0        0     1014
# 1739  481890  KR7481890002   엔에이치스팩31호   ST     0.0        0     1014
# 1740  482520  KR7482520004     교보16호스팩   ST     0.0        0     1014
# 1741  482680  KR7482680006  미래에셋비전스팩7호   ST     0.0        0     1014
# 1742  486630  KR7486630007    KB제30호스팩   ST     0.0        0     1014
#
#       지수업종소분류 벤처기업 저유동성 KRX  ETP KRX100 KRX자동차 KRX반도체 KRX바이오 KRX은행 SPAC  \
# 7        1024    N    N   Y  NaN      N      N      N      N     N    N
# 8           0    N    N   N  NaN      N      N      N      N     N    N
# 9           0    N    N   N  NaN      N      N      N      N     N    N
# 10       1024    N    N   Y  NaN      N      N      N      Y     N    N
# 11       1021    N    N   N  NaN      N      N      N      N     N    N
# ...       ...  ...  ...  ..  ...    ...    ...    ...    ...   ...  ...
# 1738        0  NaN    N   N  NaN      N    NaN    NaN    NaN   NaN    Y
# 1739        0  NaN    N   N  NaN      N    NaN    NaN    NaN   NaN    Y
# 1740        0  NaN    N   N  NaN      N    NaN    NaN    NaN   NaN    Y
# 1741        0  NaN    N   N  NaN      N    NaN    NaN    NaN   NaN    Y
# 1742        0  NaN    N   N  NaN      N    NaN    NaN    NaN   NaN    Y
#
#      KRX에너지화학 KRX철강  단기과열 KRX미디어통신 KRX건설 투자주의 KRX증권 KRX선박 KRX섹터_보험 KRX섹터_운송  \
# 7           N     N     0        N     N    N     N     N        N        N
# 8           N     N     0        N     N    N     N     N        N        N
# 9           N     N     0        N     N    N     N     N        N        N
# 10          N     N     0        N     N    N     N     N        N        N
# 11          N     N     0        N     N    N     N     N        N        N
# ...       ...   ...   ...      ...   ...  ...   ...   ...      ...      ...
# 1738      NaN   NaN     0      NaN   NaN    N   NaN   NaN      NaN      NaN
# 1739      NaN   NaN     0      NaN   NaN    N   NaN   NaN      NaN      NaN
# 1740      NaN   NaN     0      NaN   NaN    N   NaN   NaN      NaN      NaN
# 1741      NaN   NaN     0      NaN   NaN    N   NaN   NaN      NaN      NaN
# 1742      NaN   NaN     0      NaN   NaN    N   NaN   NaN      NaN      NaN
#
#      KOSDAQ150     기준가  매매수량단위  시간외수량단위 거래정지 정리매매 관리종목  시장경고 경고예고 불성실공시 우회상장  \
# 7            Y  140600       1        1    N    N    N     0    N     N    N
# 8            N   21000       1        1    N    N    N     0    N     N    N
# 9            N    1125       1        1    N    N    N     0    N     N    N
# 10           N    7280       1        1    N    N    N     0    N     N    N
# 11           N    1671       1        1    N    N    N     0    N     N    N
# ...        ...     ...     ...      ...  ...  ...  ...   ...  ...   ...  ...
# 1738         N    2035       1        1    N    N    N     0    N     N    N
# 1739         N    2030       1        1    N    N    N     0    N     N    N
# 1740         N    2040       1        1    N    N    N     0    N     N    N
# 1741         N    1985       1        1    N    N    N     0    N     N    N
# 1742         N    2000       1        1    N    N    N     0    N     N    N
#
#       락구분  액면변경  증자구분  증거금비율 신용가능  신용기간    전일거래량  액면가      상장일자   상장주수  \
# 7       0     0     0    100    N    90   446863  500  20001004  23457
# 8       0     0     0    100    N    90    66427  500  19930324   6227
# 9       0     0     0    100    N    90   157508  100  19940628  24277
# 10      0     0     0    100    N    90    11377  500  20000615  13042
# 11      0     0     0    100    N    90    14148  500  20000104  22137
# ...   ...   ...   ...    ...  ...   ...      ...  ...       ...    ...
# 1738    0     0     0    100    N    90    67077  100  20240626   6870
# 1739    0     0     0    100    N    90    82573  100  20240726   6345
# 1740    0     0     0    100    N    90    10771  100  20240813   6100
# 1741    0     0     0    100    N    90    76208  100  20240911   8215
# 1742    0     0     0    100    N    90  1532743  100  20240925   5310
#
#               자본금  결산월  공모가  우선주  공매도과열 이상급등 KRX300   매출액  영업이익  경상이익  당기순이익  \
# 7     11728736000   12  NaN    0    NaN    N      Y  1033    40    72     41
# 8      3113565000   12  NaN    0    NaN    N      N   230   -15   -13    -13
# 9      2427754000   12  NaN    0    NaN    N      N    38     4    -4     -7
# 10     6521210000   12  NaN    0    NaN    N      N  1329    47   224    174
# 11    11068750000   12  NaN    0    NaN    N      N   882    10    48     41
# ...           ...  ...  ...  ...    ...  ...    ...   ...   ...   ...    ...
# 1738    687000000   12  NaN    0    NaN    N      N     0     0     0      0
# 1739    634500000   12  NaN    0    NaN    N      N     0     0     0      0
# 1740    610000000   12  NaN    0    NaN    N      N     0     0     0      0
# 1741    821500000   12  NaN    0    NaN    N      N     0     0     0      0
# 1742    531000000   12  NaN    0    NaN    N      N     0     0     0      0
#
#       ROE        기준년월   시가총액 그룹사코드 회사신용한도초과 담보대출가능 대주가능
# 7       1  20240630.0  32981   NaN        N      N    N
# 8      -5  20240630.0   1307   NaN        N      N    N
# 9      -4  20231231.0    273   NaN        N      N    N
# 10     22  20240630.0    949   NaN        N      N    N
# 11      4  20240630.0    369   NaN        N      N    N
# ...   ...         ...    ...   ...      ...    ...  ...
# 1738    0         NaN    139   NaN        N      N    N
# 1739    0         NaN    128   NaN        N      N    N
# 1740    0         NaN    124   NaN        N      N    N
# 1741    0         NaN    163   NaN        N      N    N
# 1742    0         NaN    106   NaN        N      N    N
#
# [1736 rows x 67 columns]

# %%
filtered_kospi = symbols_kospi[symbols_kospi['그룹코드'] == 'ST']
filtered_kosdaq = symbols_kosdaq[symbols_kosdaq['그룹코드'] == 'ST']

# 두 DataFrame 합치기
combined_symbols = pd.concat([filtered_kospi, filtered_kosdaq])

# 값 치환 (N -> S, Y -> A)
combined_symbols['거래정지'] = combined_symbols['거래정지'].replace({'N': 'S', 'Y': 'A'})
columns_to_keep = ['단축코드', '한글명', '표준코드', '시가총액', '거래정지']

combined_symbols = combined_symbols[columns_to_keep]

combined_symbols[combined_symbols['단축코드'] == '900270']
# Out:
# 103     000020
# 104     000040
# 105     000050
# 106     000070
# 107     000075
#          ...
# 1738    479880
# 1739    481890
# 1740    482520
# 1741    482680
# 1742    486630
# Name: 단축코드, Length: 2665, dtype: object

# %%
duplicated_shortcodes = combined_symbols[combined_symbols['단축코드'].duplicated(keep=False)]

# 중복된 값이 있는지 여부 확인
if not duplicated_shortcodes.empty:
    print("중복된 shortcode가 존재합니다:")
    print(duplicated_shortcodes)
else:
    print("중복된 shortcode가 없습니다.")
# Out:
# 중복된 shortcode가 없습니다.

# %%
combined_symbols.to_csv("stock_info.csv", index=True, encoding="utf-8-sig")

# %%
import pymysql

# MySQL 연결 설정
connection = pymysql.connect(
    host=DB_HOST,     # MySQL 서버 주소
    user=DB_USERNAME,       # MySQL 사용자 이름
    password=DB_PASSWORD,   # MySQL 비밀번호
    database=DB_SCHEME    # 사용할 데이터베이스 이름
)

# %%
# SQL 쿼리 실행
cursor = connection.cursor()

# cursor.execute("SELECT * FROM SUB_CATEGORY")
cursor.execute('desc STOCK')
result = cursor.fetchall()

# for row in result:
    # print(row)
result
# Out:
# (('STOCK_ID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('SHORT_CODE', 'varchar(6)', 'NO', 'PRI', None, ''),
#  ('SUB_CATEGORY_ID', 'int', 'NO', 'MUL', None, ''),
#  ('STOCK_NAME', 'varchar(20)', 'YES', '', None, ''),
#  ('STANDARD_CODE', 'varchar(12)', 'NO', '', None, ''),
#  ('STOCK_EXCHANGE_MARKET', 'char(1)', 'YES', '', None, ''),
#  ('MARKET_CAPITALIZATION', 'varchar(10)', 'YES', '', None, ''),
#  ('OPEN_PRICE', 'int', 'YES', '', None, ''),
#  ('CLOSED_PRICE', 'int', 'YES', '', None, ''),
#  ('HIGH_PRICE', 'int', 'YES', '', None, ''),
#  ('LOW_PRICE', 'int', 'YES', '', None, ''),
#  ('STOCK_TRADE_STATUS', 'char(1)', 'YES', '', None, ''),
#  ('CREATED_AT',
#   'timestamp',
#   'YES',
#   '',
#   'CURRENT_TIMESTAMP',
#   'DEFAULT_GENERATED'),
#  ('UPDATED_AT', 'timestamp', 'YES', '', None, ''))

# %%
from sqlalchemy import create_engine, MetaData, Table
# MySQL 데이터베이스 연결 설정
db_username = DB_USERNAME
db_password = DB_PASSWORD
db_host = DB_HOST
db_name = DB_SCHEME

# 데이터프레임 컬럼명과 데이터베이스 컬럼명을 매핑하는 딕셔너리 생성

# SQLAlchemy 엔진 생성
engine = create_engine(f'mysql+pymysql://{db_username}:{db_password}@{db_host}/{db_name}')

# 메타데이터 객체 생성
metadata = MetaData()

table_name = 'STOCK'
table = Table(table_name, metadata, autoload_with=engine)

# 테이블 컬럼명 확인
db_columns = [column.name for column in table.columns]

db_columns
# Out:
# ['STOCK_ID',
#  'SHORT_CODE',
#  'SUB_CATEGORY_ID',
#  'STOCK_NAME',
#  'STANDARD_CODE',
#  'STOCK_EXCHANGE_MARKET',
#  'MARKET_CAPITALIZATION',
#  'OPEN_PRICE',
#  'CLOSED_PRICE',
#  'HIGH_PRICE',
#  'LOW_PRICE',
#  'STOCK_TRADE_STATUS',
#  'CREATED_AT',
#  'UPDATED_AT']

# %%
column_mapping = {
    '단축코드': 'SHORT_CODE',
    '서브카테고리' : 'SUB_CATEGORY_ID',
    '한글명': 'STOCK_NAME',
    '표준코드': 'STANDARD_CODE',
    '거래소': 'STOCK_EXCHANGE_MARKET',
    '시가총액': 'MARKET_CAPITALIZATION',
    '시가': 'OPEN_PRICE',
    '종가': 'CLOSED_PRICE',
    '고가': 'HIGH_PRICE',
    '저가': 'LOW_PRICE',
    '거래정지': 'STOCK_TRADE_STATUS',
}

# 컬럼명 매핑 적용
combined_symbols.rename(columns=column_mapping, inplace=True)

# %%
for column in [
 'SHORT_CODE',
 'SUB_CATEGORY_ID',
 'STOCK_NAME',
 'STANDARD_CODE',
 'STOCK_EXCHANGE_MARKET',
 'MARKET_CAPITALIZATION',
 'OPEN_PRICE',
 'CLOSED_PRICE',
 'HIGH_PRICE',
 'LOW_PRICE',
 'STOCK_TRADE_STATUS']:
    if column not in combined_symbols.columns:
        combined_symbols[column] = 1

# %%
combined_symbols
# Out:
#      SHORT_CODE  STOCK_NAME STANDARD_CODE  MARKET_CAPITALIZATION  \
# 103      000020        동화약품  KR7000020008                   2153
# 104      000040       KR모터스  KR7000040006                    341
# 105      000050          경방  KR7000050005                   1732
# 106      000070       삼양홀딩스  KR7000070003                   6774
# 107      000075      삼양홀딩스우  KR7000071001                    172
# ...         ...         ...           ...                    ...
# 1737     479880    한국제15호스팩  KR7479880007                    139
# 1738     481890   엔에이치스팩31호  KR7481890002                    128
# 1739     482520     교보16호스팩  KR7482520004                    124
# 1740     482680  미래에셋비전스팩7호  KR7482680006                    163
# 1741     486630    KB제30호스팩  KR7486630007                    106
#
#      STOCK_TRADE_STATUS  SUB_CATEGORY_ID  STOCK_EXCHANGE_MARKET  OPEN_PRICE  \
# 103                   S                1                      1           1
# 104                   S                1                      1           1
# 105                   S                1                      1           1
# 106                   S                1                      1           1
# 107                   S                1                      1           1
# ...                 ...              ...                    ...         ...
# 1737                  S                1                      1           1
# 1738                  S                1                      1           1
# 1739                  S                1                      1           1
# 1740                  S                1                      1           1
# 1741                  S                1                      1           1
#
#       CLOSED_PRICE  HIGH_PRICE  LOW_PRICE
# 103              1           1          1
# 104              1           1          1
# 105              1           1          1
# 106              1           1          1
# 107              1           1          1
# ...            ...         ...        ...
# 1737             1           1          1
# 1738             1           1          1
# 1739             1           1          1
# 1740             1           1          1
# 1741             1           1          1
#
# [2663 rows x 11 columns]

# %%
combined_symbols.to_sql(name='STOCK', con=engine, if_exists='append', index=False)
# Out:
# 2663
